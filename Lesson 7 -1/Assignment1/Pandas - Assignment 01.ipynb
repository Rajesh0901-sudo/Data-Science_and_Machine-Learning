# %% [markdown]
# <img src="http://cfs22.simplicdn.net/ice9/new_logo.svgz "/>
#
# # Assignment 01: Evaluate the FAA Dataset
#
# *The comments/sections provided are your cues to perform the assignment. You don't need to limit yourself to the number of rows/cells provided. You can add additional rows in each section to add more lines of code.*
#
# *If at any point in time you need help on solving this assignment, view our demo video to understand the different steps of the code.*
#
# **Happy coding!**
#
# * * *

# %% [markdown]
# #### 1: VIew and import the dataset

# %%
#Import necessary libraries
import numpy as np
import pandas as pd

# %%
#Import the FAA (Federal Aviation Authority) dataset
df = pd.read_csv('/Users/rajeshsahu/Desktop/Lesson 7 -1/faa_ai_prelim/faa_ai_prelim.csv')

# %% [markdown]
# #### 2: View and understand the dataset

# %%
#View the dataset shape
print(df)
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
# ..     ...        ...            ...            ...           ...
# 78      No  08-FEB-16      31-DEC-15      17:00:00Z   SAN ANTONIO
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 1          Florida            NaN
# 2       New Jersey            NaN
# 3   North Carolina            NaN
# 4           Alaska            NaN
# ..             ...            ...
# 78           Texas            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3   AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# 4   AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...        Incident
# ..                                                ...             ...
# 78  AIRCRAFT ON LANDING, GROUND LOOPED, BULVERDE A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                    FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0      FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 1          FAA Miami FSDO-19  ...          NaN           NaN             NaN
# 2   FAA Philadelphia FSDO-17  ...          NaN           NaN             NaN
# 3      FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 4      FAA Anchorage FSDO-03  ...          NaN           1.0             NaN
# ..                       ...  ...          ...           ...             ...
# 78   FAA San Antonio FSDO-17  ...          NaN           NaN             NaN
# 79    FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80    FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81    FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82    FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 1            NaN         NaN            NaN            NaN              NaN
# 2            NaN         NaN            NaN            NaN              NaN
# 3            NaN         NaN            NaN            NaN              NaN
# 4            NaN         NaN            NaN            NaN              NaN
# ..           ...         ...            ...            ...              ...
# 78           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 78            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [83 rows x 42 columns]

# %%
#View the first five observations
df.head(5)
# Out:
#   UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0      No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1      No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2      No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3      No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4      No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
#
#    LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0  North Carolina            NaN
# 1         Florida            NaN
# 2      New Jersey            NaN
# 3  North Carolina            NaN
# 4          Alaska            NaN
#
#                                             RMK_TEXT EVENT_TYPE_DESC  \
# 0  AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1  AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2  AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3  AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# 4  AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...        Incident
#
#                   FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0     FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 1         FAA Miami FSDO-19  ...          NaN           NaN             NaN
# 2  FAA Philadelphia FSDO-17  ...          NaN           NaN             NaN
# 3     FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 4     FAA Anchorage FSDO-03  ...          NaN           1.0             NaN
#
#   PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0           NaN         NaN            NaN            NaN              NaN
# 1           NaN         NaN            NaN            NaN              NaN
# 2           NaN         NaN            NaN            NaN              NaN
# 3           NaN         NaN            NaN            NaN              NaN
# 4           NaN         NaN            NaN            NaN              NaN
#
#   GRND_INJ_FATAL  GRND_INJ_UNK
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
#
# [5 rows x 42 columns]

# %%
#View all the columns present in the dataset
df.columns
# Out:
# Index(['UPDATED', 'ENTRY_DATE', 'EVENT_LCL_DATE', 'EVENT_LCL_TIME',
#        'LOC_CITY_NAME', 'LOC_STATE_NAME', 'LOC_CNTRY_NAME', 'RMK_TEXT',
#        'EVENT_TYPE_DESC', 'FSDO_DESC', 'REGIST_NBR', 'FLT_NBR', 'ACFT_OPRTR',
#        'ACFT_MAKE_NAME', 'ACFT_MODEL_NAME', 'ACFT_MISSING_FLAG',
#        'ACFT_DMG_DESC', 'FLT_ACTIVITY', 'FLT_PHASE', 'FAR_PART', 'MAX_INJ_LVL',
#        'FATAL_FLAG', 'FLT_CRW_INJ_NONE', 'FLT_CRW_INJ_MINOR',
#        'FLT_CRW_INJ_SERIOUS', 'FLT_CRW_INJ_FATAL', 'FLT_CRW_INJ_UNK',
#        'CBN_CRW_INJ_NONE', 'CBN_CRW_INJ_MINOR', 'CBN_CRW_INJ_SERIOUS',
#        'CBN_CRW_INJ_FATAL', 'CBN_CRW_INJ_UNK', 'PAX_INJ_NONE', 'PAX_INJ_MINOR',
#        'PAX_INJ_SERIOUS', 'PAX_INJ_FATAL', 'PAX_INJ_UNK', 'GRND_INJ_NONE',
#        'GRND_INJ_MINOR', 'GRND_INJ_SERIOUS', 'GRND_INJ_FATAL', 'GRND_INJ_UNK'],
#       dtype='object')

# %% [markdown]
# #### 3: Extract the following attributes from the dataset:
# 1. Aircraft make name
# 2. State name
# 3. Aircraft model name
# 4. Text information
# 5. Flight phase
# 6. Event description type
# 7. Fatal flag

# %%
#Create a new dataframe with only the required columns
df['ACFT_MAKE_NAME']
# Out:
# 0              BEECH
# 1               VANS
# 2             CESSNA
# 3            LANCAIR
# 4             CESSNA
#            ...
# 78           AERONCA
# 79    NORTH AMERICAN
# 80          CHAMPION
# 81             BEECH
# 82            CESSNA
# Name: ACFT_MAKE_NAME, Length: 83, dtype: object

# %%
#View the type of the object
df.dtypes
# Out:
# UPDATED                 object
# ENTRY_DATE              object
# EVENT_LCL_DATE          object
# EVENT_LCL_TIME          object
# LOC_CITY_NAME           object
# LOC_STATE_NAME          object
# LOC_CNTRY_NAME          object
# RMK_TEXT                object
# EVENT_TYPE_DESC         object
# FSDO_DESC               object
# REGIST_NBR              object
# FLT_NBR                 object
# ACFT_OPRTR              object
# ACFT_MAKE_NAME          object
# ACFT_MODEL_NAME         object
# ACFT_MISSING_FLAG      float64
# ACFT_DMG_DESC           object
# FLT_ACTIVITY            object
# FLT_PHASE               object
# FAR_PART               float64
# MAX_INJ_LVL             object
# FATAL_FLAG              object
# FLT_CRW_INJ_NONE       float64
# FLT_CRW_INJ_MINOR      float64
# FLT_CRW_INJ_SERIOUS    float64
# FLT_CRW_INJ_FATAL      float64
# FLT_CRW_INJ_UNK        float64
# CBN_CRW_INJ_NONE       float64
# CBN_CRW_INJ_MINOR      float64
# CBN_CRW_INJ_SERIOUS    float64
# CBN_CRW_INJ_FATAL      float64
# CBN_CRW_INJ_UNK        float64
# PAX_INJ_NONE           float64
# PAX_INJ_MINOR          float64
# PAX_INJ_SERIOUS        float64
# PAX_INJ_FATAL          float64
# PAX_INJ_UNK            float64
# GRND_INJ_NONE          float64
# GRND_INJ_MINOR         float64
# GRND_INJ_SERIOUS       float64
# GRND_INJ_FATAL         float64
# GRND_INJ_UNK           float64
# dtype: object

# %%
#Check if the dataframe contains all the required attributes
row,column=df.shape
if column==0:
    print('NO')
else:
    print('YES')
# Out:
# YES

# %% [markdown]
# #### 4. Clean the dataset and replace the fatal flag NaN with “No”

# %%
#Replace all Fatal Flag missing values with the required output
cleaned_df=df.fillna('No')

# %%
#Verify if the missing values are replaced
cleaned_df
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
# ..     ...        ...            ...            ...           ...
# 78      No  08-FEB-16      31-DEC-15      17:00:00Z   SAN ANTONIO
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina             No
# 1          Florida             No
# 2       New Jersey             No
# 3   North Carolina             No
# 4           Alaska             No
# ..             ...            ...
# 78           Texas             No
# 79         Arizona             No
# 80      California             No
# 81      California             No
# 82         Alabama             No
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3   AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# 4   AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...        Incident
# ..                                                ...             ...
# 78  AIRCRAFT ON LANDING, GROUND LOOPED, BULVERDE A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                    FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0      FAA Charlotte FSDO-68  ...           No            No              No
# 1          FAA Miami FSDO-19  ...           No            No              No
# 2   FAA Philadelphia FSDO-17  ...           No            No              No
# 3      FAA Charlotte FSDO-68  ...           No            No              No
# 4      FAA Anchorage FSDO-03  ...           No           1.0              No
# ..                       ...  ...          ...           ...             ...
# 78   FAA San Antonio FSDO-17  ...           No            No              No
# 79    FAA Scottsdale FSDO-07  ...           No            No              No
# 80    FAA Long Beach FSDO-05  ...           No            No              No
# 81    FAA Long Beach FSDO-05  ...           No            No              No
# 82    FAA Birmingham FSDO-09  ...           No            No              No
#
#    PAX_INJ_FATAL PAX_INJ_UNK GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0             No          No            No             No               No
# 1             No          No            No             No               No
# 2             No          No            No             No               No
# 3             No          No            No             No               No
# 4             No          No            No             No               No
# ..           ...         ...           ...            ...              ...
# 78            No          No            No             No               No
# 79            No          No            No             No               No
# 80            No          No            No             No               No
# 81            No          No            No             No               No
# 82            No          No            No             No               No
#
#    GRND_INJ_FATAL GRND_INJ_UNK
# 0              No           No
# 1              No           No
# 2              No           No
# 3              No           No
# 4              No           No
# ..            ...          ...
# 78             No           No
# 79             No           No
# 80             No           No
# 81             No           No
# 82             No           No
#
# [83 rows x 42 columns]

# %%
#Check the number of observations
row,column=df.shape
row
# Out:
# 83

# %% [markdown]
# #### 5. Remove all the observations where aircraft names are not available

# %%
#Drop the unwanted values/observations from the dataset
new_df = df[df['FSDO_DESC'].notna()]
new_df[]
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
# ..     ...        ...            ...            ...           ...
# 78      No  08-FEB-16      31-DEC-15      17:00:00Z   SAN ANTONIO
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 1          Florida            NaN
# 2       New Jersey            NaN
# 3   North Carolina            NaN
# 4           Alaska            NaN
# ..             ...            ...
# 78           Texas            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3   AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# 4   AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...        Incident
# ..                                                ...             ...
# 78  AIRCRAFT ON LANDING, GROUND LOOPED, BULVERDE A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                    FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0      FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 1          FAA Miami FSDO-19  ...          NaN           NaN             NaN
# 2   FAA Philadelphia FSDO-17  ...          NaN           NaN             NaN
# 3      FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 4      FAA Anchorage FSDO-03  ...          NaN           1.0             NaN
# ..                       ...  ...          ...           ...             ...
# 78   FAA San Antonio FSDO-17  ...          NaN           NaN             NaN
# 79    FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80    FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81    FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82    FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 1            NaN         NaN            NaN            NaN              NaN
# 2            NaN         NaN            NaN            NaN              NaN
# 3            NaN         NaN            NaN            NaN              NaN
# 4            NaN         NaN            NaN            NaN              NaN
# ..           ...         ...            ...            ...              ...
# 78           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 78            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [81 rows x 42 columns]

# %% [markdown]
# #### 6. Find the aircraft types and their occurrences in the dataset

# %%
#Check the number of observations now to compare it with the original dataset and see how many values have been dropped
row1,col1 = df.shape
row2,col2 = new_df.shape
row1-row2
# Out:
# 2

# %%
#Group the dataset by aircraft name
grouped_df_by_AC_name = new_df.groupby('FSDO_DESC')

# %% [raw]
# #View the number of times each aircraft type appears in the dataset (Hint: use the size() method)

# %%
grouped_df_by_AC_name.size()
# Out:
# FSDO_DESC
# FAA Anchorage FSDO-03         3
# FAA Atlanta FSDO-11           1
# FAA Baltimore FSDO-07         2
# FAA Baton Rouge FSDO-03       2
# FAA Birmingham FSDO-09        1
# FAA Boise FSDO-11             1
# FAA Boston FSDO-61            2
# FAA Charleston FSDO-09        1
# FAA Charlotte FSDO-68         2
# FAA Columbus FSDO-07          1
# FAA Denver FSDO-03            1
# FAA East Michigan FSDO-23     1
# FAA Farmingdale FSDO-11       1
# FAA Fresno FSDO-17            1
# FAA Grand Rapids FSDO-09      1
# FAA Harrisburg FSDO-13        1
# FAA Helena FSDO-05            1
# FAA Honolulu FSDO-13          1
# FAA Houston FSDO-09           2
# FAA Kansas City FSDO-63       1
# FAA Little Rock FSDO-11       2
# FAA Long Beach FSDO-05        3
# FAA Lubbock FSDO-13           1
# FAA Miami FSDO-19             7
# FAA Minneapolis FSDO-15       1
# FAA Nashville FSDO-19         1
# FAA Oakland FSDO-27           2
# FAA Oklahoma City FSDO-15     1
# FAA Orlando FSDO-15           5
# FAA Philadelphia FSDO-17      1
# FAA Portland FSDO-09          3
# FAA Portland FSDO-65          1
# FAA Rapid City FSDO-27        1
# FAA Reno FSDO-11              1
# FAA Richmond FSDO-21          2
# FAA Riverside FSDO-21         2
# FAA Rochester FSDO-23         1
# FAA Sacramento FSDO-25        1
# FAA Salt Lake City FSDO-07    1
# FAA San Antonio FSDO-17       2
# FAA San Jose FSDO-15          4
# FAA Scottsdale FSDO-07        5
# FAA Van Nuys FSDO-01          3
# FAA Washington FSDO-27        1
# FAA Wichita FSDO-64           2
# dtype: int64

# %% [markdown]
# #### 7: Display the observations where fatal flag is “Yes”

# %%
#Group the dataset by fatal flag
grouped_df_by_FATAL_FLAG = new_df.groupby('FATAL_FLAG')

# %%
#View the total number of fatal and non-fatal accidents
x= int(grouped_df_by_FATAL_FLAG.size())

print(x,row2-x)
# Out:
# 7 74

# %%
#Create a new dataframe to view only the fatal accidents (Fatal Flag values = Yes)
fatal_accidents = grouped_df_by_FATAL_FLAG.get_group('Yes')
fatal_accidents
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 22      No  17-FEB-16      16-FEB-16      20:52:00Z       BUCKEYE
# 55      No  11-FEB-16      11-FEB-16      00:17:00Z        TULARE
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 22         Arizona            NaN
# 55      California            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
#                                              RMK_TEXT EVENT_TYPE_DESC  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 22  AIRCRAFT, LIGHT SPORT EVOLUTION REVO,  ON TAKE...        Accident
# 55  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES A...        Accident
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...        Accident
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 81  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...        Accident
# 82  N784CP AIRCRAFT CRASHED INTO A WOODED AREA NEA...        Accident
#
#                  FSDO_DESC  ... PAX_INJ_NONE PAX_INJ_MINOR PAX_INJ_SERIOUS  \
# 0    FAA Charlotte FSDO-68  ...          NaN           NaN             NaN
# 22  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 55      FAA Fresno FSDO-17  ...          NaN           NaN             NaN
# 79  FAA Scottsdale FSDO-07  ...          NaN           NaN             NaN
# 80  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 81  FAA Long Beach FSDO-05  ...          NaN           NaN             NaN
# 82  FAA Birmingham FSDO-09  ...          NaN           NaN             NaN
#
#    PAX_INJ_FATAL PAX_INJ_UNK  GRND_INJ_NONE GRND_INJ_MINOR GRND_INJ_SERIOUS  \
# 0            NaN         NaN            NaN            NaN              NaN
# 22           NaN         NaN            NaN            NaN              NaN
# 55           NaN         NaN            NaN            NaN              NaN
# 79           NaN         NaN            NaN            NaN              NaN
# 80           NaN         NaN            NaN            NaN              NaN
# 81           NaN         NaN            NaN            NaN              NaN
# 82           NaN         NaN            NaN            NaN              NaN
#
#    GRND_INJ_FATAL  GRND_INJ_UNK
# 0             NaN           NaN
# 22            NaN           NaN
# 55            NaN           NaN
# 79            NaN           NaN
# 80            NaN           NaN
# 81            NaN           NaN
# 82            NaN           NaN
#
# [7 rows x 42 columns]
