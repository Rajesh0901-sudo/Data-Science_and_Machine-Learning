# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = sns.load_dataset('iris')

# %%
grid_dataset = sns.FacetGrid(dataset,col='species')
grid_dataset.map(plt.hist,'sepal_length')

# %%
dataset= sns.load_dataset('flights')

# %%
d = sns.PairGrid(dataset)
d.map(plt.scatter)

# %%
data = dataset.pivot('month','year','passengers')

# %%
d = sns.PairGrid(data)
d.map(plt.scatter)
